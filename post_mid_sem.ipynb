# %% [markdown]
# <a href="https://colab.research.google.com/github/sachin-kanmus3245/Python-course/blob/Python--CS-2001/post_mid_sem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Functions

# %%
pi=3.14
def area_of_circle(r):
  area=pi*r**2
  return area #gives back calculated value
a=area_of_circle(5)
print(a)
# Out:
# 78.5

# %% [markdown]
# #RETURN
# * tells the function ends here
# * increases readability
# * decreases line of code

# %% [markdown]
# #PASS

# %%
#with o(n)
def prime_number(n):
  if n<=1:
    return False
  if n<=3:
    return True
  for i in range(2,n):
    if n%i==0:
      return False
    return True

a=prime_number(4)
print(a)
# Out:
# False

# %%
#with o(root(n))
import math
def prime_number(n):
  if n<=1:
    return False
  if n<=3:
    return True
  if n%2==0:
   return False
  for i in range(3,math.sqrt(n)):
    if n%i==0:
      return False
    return True

a=prime_number(4)
print(a)
# Out:
# False

# %%
def calculator(a,b):
 return a+b,a-b,a*b,a/b
print(calculator(5,4))
# Out:
# (9, 1, 20, 1.25)

# %% [markdown]
# *use of prime numbers

# %% [markdown]
# 1. wite a fn that take string as a inpt return uppercase
# 2. write a function with the name email_validator
# 3. password validator
# 4. function to validate simple interest

# %%
def string(s):
   return s.upper(),s.title()
a=input("ENter the string:")
x,y=string(a)
print(x)
print(y)
# Out:
# ENter the string:hdj
# HDJ
# Hdj

# %%
# *args and **kwargs
def my_family(*args):
  print("The youngest child is "+args[1])
  print("Type",type(args))
  print("First argument is ",args[0])
my_family("Amit","shiva","Avantika")
# Out:
# The youngest child isshiva
# Type <class 'tuple'>
# First argument Amit

# %%
def sec_D(greeting,*names):
  for name in names:
   print(greeting,name)

sec_D("Hello","Swati","Amit","Shiva")
# Out:
# Hello Swati
# Hello Amit
# Hello Shiva

# %%
def total_marks(*marks):
 total=0
 for mark in marks:
   total+=mark
 return total
a=total_marks(35,32,33,24,36)
print("total sum is:",a)
# Out:
# total sum is: 160

# %%
def my_family(**child):
  print("Type",type(child))
  print("Name:",child["name"])
  print("Age:",child["age"])
  print(child)
my_family(name="Sachin",age=33,city="ranchi")
# Out:
# Type <class 'dict'>
# Name: Sachin
# Age: 33
# {'name': 'Sachin', 'age': 33, 'city': 'ranchi'}

# %%
def my_fun(title,*args,**kwargs):
  print("Title:",title)
  print("positional argument",args)
  print("keyword arguments",kwargs)
my_fun("userinfo","nitika","swti",age=29,city="lko")
# Out:
# Title: userinfo
# positional argument ('nitika', 'swti')
# keyword arguments {'age': 29, 'city': 'lko'}

# %%
#unpacking
def my_fun(a,b,c):
  return a+b+c
num=[1,2,3]
result =my_fun(*num)
print(result)
# Out:
# 6

# %%
def my_details(fname,lname):
 print("hello",fname,lname)
person={"fname":"Nitika",
        "lname":"Nigam"}
my_details(**person)
# Out:
# hello Nitika Nigam

# %%
#crate a function student_profile with key word arguments that prints the formated message
#"amit is 22 year old and is studying btech"
def student_profile(**kwargs):
  a=kwargs.get('name',0)
  b=kwargs.get('age',0)
  c=kwargs.get('course',0)
  print(f"{a} is {b} year old and is studying {c}")
student_profile(name="amit",age=22,course="btech")
student_profile(name="sachin",age=20,course="btech")
# Out:
# amit is 22 year old and is studying btech
# sachin is 20 year old and is studying btech

# %% [markdown]
# define a function rectangle_perimeter_area that takes the length and breadth as parameter return both area and perimeter for the rectangle for the function for different set of length values

# %%
def  rectangle_perimeter_area(l,b):
  return l*b,2*(l+b)
a1,p1= rectangle_perimeter_area(4,5)
a2,p2= rectangle_perimeter_area(6,7)
print("Area1:",a1,"Perimeter1:",p1)
print("Area2:",a2,"Perimeter2:",p2)
# Out:
# Area1: 20 Perimeter1: 18
# Area2: 42 Perimeter2: 26

# %%
#define a function list_summary that accepts a list of integers returns sum,average and maximum value of list as a tupple
def list_summary(a):
  sum=0
  for i in a:
    sum+=i
  avg=sum/len(a)
  max=a[0]
  for i in a:
    if i>max:
      max=i
  return sum,avg,max
print(list_summary([12,13,14,15,10,11]))
# Out:
# (75, 12.5, 15)

# %%
#import hte date time module then define a function get_day_of_week that takes the date string in yyyy-mm-dd
#use datetime.strptime() to convert the date string into dte time object and then use strftime(%A) to get the day of the week
import datetime as dt
def get_day_of_week(date_str):
  date_obj=dt.datetime.strptime(date_str,"%Y-%m-%d")
  day=date_obj.strftime("%D")
  time=dt.datetime.now()
  print(time)
  return day


print(get_day_of_week("2025-11-12"))
# Out:
# 2025-11-12 11:08:51.939443
# 11/12/25

# %% [markdown]
# Q. Implement a function global_median that maintains a global list of numbers and return the current median

# %%
num =[1,2,4,6,8,10,13]
def global_median(n):
  global num
  num.append(n)
  num.sort()
  n=len(num)
  mid=n//2
  if n%2==0:
    return (num[mid-1]+num[mid])/2
  else:
    return num[mid]
print(global_median(6))
# Out:
# 6.0

# %%
num=1
num=[1,2,3,4]
def modify():
  num=2
  num=num+1
  print(num)
modify()
print(num)
# Out:
# 3
# [1, 2, 3, 4]

# %%
import time
num=list(range(100))#constructor of list
target=99
start=time.time()
print(target in num)
print("time:",time.time()-start)

num_set=set(range(100))
start=time.time()
print(target in num_set)
print("time:",time.time()-start)
# Out:
# True
# time: 0.00023818016052246094
# True
# time: 0.00011491775512695312

# %%
def set_operations(a,b):
  return a|b,a&b,a-b,a.issubset(b),a.issuperset(b)
a={1,2,3,4,5}
b={2,4,5,7,8}
x1,x2,x3,x4,x5=set_operations(a,b)
print("union:",x1)
print("intersection:",x2)
print(x3,x4,x5)
# Out:
# union: {1, 2, 3, 4, 5, 7, 8}
# intersection: {2, 4, 5}
# {1, 3} False False

# %%
s=set(["10",10])
print(s)
# Out:
# {'10', 10}

# %%
x=set("hello")
print(x)
# Out:
# {'h', 'e', 'o', 'l'}

# %%
def check(item,basket):
  basket.add(item)
  return basket
b={"apple","banana"}
print(check("banana",b))
print(check("orange",b))
"""this says that set are mutable"""
# Out:
# {'apple', 'banana'}
# {'apple', 'banana', 'orange'}

# %%
a=[1,2,3,5,6,7,8]
s=set(a)
A=set(range(len(a)+1))
print(A-s)
# Out:
# {0, 4}

# %% [markdown]
# Q.crush matching problem

# %%
c1={"coding","kdrama","coffee"}
c2={"coffee","gym","travel"}
mine={"coding","coffee"}
print("you have future with c1",(mine.issubset(c1)))
print("you have future with c2",(mine.issubset(c2)))
# Out:
# you have future with c1 True
# you have future with c2 False

# %% [markdown]
# Given a list of integers you need to extract alternate numbers

# %%
def extraction (arr):
  if len(arr)==0: return []
  else:
    return arr[::2]
print(extraction([1,2,3,4,5,6,7,8,9]))
# Out:
# [1, 3, 5, 7, 9]

# %%
def extract(arr):
  if len(arr)==0:
    return "invalid"
  new_arr = [] # Initialize new_arr here
  for i in range(0,len(arr),2):
   new_arr.append(arr[i])
  return new_arr
res=extract([1,2,3,4,5,6,7,8,9,0])
print(res)
#use: optimises the code
# Out:
# [1, 3, 5, 7, 9]

# %%
def binary_search(arr,value):
  l = 0;
  e = len(arr)-1
  while(l<=e):
    mid = l + (e-l)//2
    if(arr[mid]==value):
      return mid;
    if(arr[mid]<value):
      l = mid+1
    else :
      e = mid-1
  return 'Not found'
print(binary_search([1,2,3,4,5],2))
# Out:
# 1

# %%
def search_n(arr,tar):# linear search
  for i in range(0,len(arr)):
    if arr[i]==tar:
      return i
    return "DNE"
def search_logn(arr,tar): # binary search
  l=0
  r=len(arr)-1
  while l<=r:
    mid=(l+r)//2
    if arr[mid]==tar:
      return mid
    elif arr[mid]<tar:
      l=mid+1
    elif arr[mid]>tar:
      r=mid-1
  return -1
def search_O1(arr,tar): # using set
  set_arr=set(arr)
  if tar in set_arr:
    return arr.index(tar)
  return -1
arr=input("enter array:").split() # split kiya spaces ke through
arr=[int(i) for i in arr] # jo split tokens mile strings jaise...unko strings mai badla
tar=int(input("enter ur target:"))
print(search_n(arr,tar))
print(search_logn(arr,tar))
print(search_O1(arr,tar))
# Out:
# enter array:1 2 3 4 5 6 7 8
# enter ur target:7
# DNE
# 6
# 6

# %%
def search_with_set(arr,value):
  arr_set = set(arr)
  if(value in arr_set): return 'Found'
  return 'Not Found'
print(search_with_set([12,2,3,4,5,6],12))
# Out:
# Found

# %% [markdown]
# # bubble sort

# %%
def bubbleSort(arr):
    n = len(arr)
    for i in range(n):
        swap = False
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
                swap= True
        if (not swap):
            break
    return arr
print(bubbleSort([1,5,6,3]))
# Out:
# [1, 3, 5, 6]

# %% [markdown]
# # Quick Sort

# %% [markdown]
# # Selection Sort

# %%
def selection_sort(arr):
    n = len(arr)

    for i in range(n):
        min_index = i

        # Find the smallest element in remaining array
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j

        # Swap smallest element with current position
        arr[i], arr[min_index] = arr[min_index], arr[i]

    return arr


# Example
arr = [64, 25, 12, 22, 11]
print(selection_sort(arr))

# %% [markdown]
# #radix sort
# # Python program for implementation of Radix Sort
# # A function to do counting sort of arr[] according to
# # the digit represented by exp.

# %%
#radix sort
# Python program for implementation of Radix Sort
# A function to do counting sort of arr[] according to
# the digit represented by exp.


def countingSort(arr, exp1):

    n = len(arr)

    # The output array elements that will have sorted arr
    output = [0] * (n)

    # initialize count array as 0
    count = [0] * (10)

    # Store count of occurrences in count[]
    for i in range(0, n):
        index = arr[i] // exp1
        count[index % 10] += 1

    # Change count[i] so that count[i] now contains actual
    # position of this digit in output array
    for i in range(1, 10):
        count[i] += count[i - 1]

    # Build the output array
    i = n - 1
    while i >= 0:
        index = arr[i] // exp1
        output[count[index % 10] - 1] = arr[i]
        count[index % 10] -= 1
        i -= 1

    # Copying the output array to arr[],
    # so that arr now contains sorted numbers
    i = 0
    for i in range(0, len(arr)):
        arr[i] = output[i]

# Method to do Radix Sort
def radixSort(arr):
    # Find the maximum number to know number of digits
    max1 = max(arr)
    # Do counting sort for every digit. Note that instead
    # of passing digit number, exp is passed. exp is 10^i
    # where i is current digit number
    exp = 1
    while max1 / exp >= 1:
        countingSort(arr, exp)
        exp *= 10


# Driver code
arr = [170, 45, 75, 90, 802, 24, 2, 66]

# Function Call
radixSort(arr)

for i in range(len(arr)):
    print(arr[i], end=" ")

# This code is contributed by Mohit Kumra
# Edited by Patrick Gallagher

# %% [markdown]
# application of sorting and searching and optimized codes

# %% [markdown]
# # all searches and sorts
# #Lamda Function
# # explore libraries
# # date time, maths , mathplotlib
